# %% [markdown]
# # Data Loading, Storage and File Formats
# Problem Statement: Analyzing Sales Data from Multiple File Formats
# Dataset: Sales data in multiple file formats (e.g., CSV, Excel, JSON)
# Description: The goal is to load and analyze sales data from different file formats, including
# CSV, Excel, and JSON, and perform data cleaning, transformation, and analysis on the
# dataset.
# Tasks to Perform:
# Obtain sales data files in various formats, such as CSV, Excel, and JSON.
# 1. Load the sales data from each file format into the appropriate data structures or
# dataframes.
# 2. Explore the structure and content of the loaded data, identifying any inconsistencies,
# missing values, or data quality issues.
# 3. Perform data cleaning operations, such as handling missing values, removing
# duplicates, or correcting inconsistencies.
# 4. Convert the data into a unified format, such as a common dataframe or data structure,
# to enable seamless analysis.
# 5. Perform data transformation tasks, such as merging multiple datasets, splitting
# columns, or deriving new variables.
# 6. Analyze the sales data by performing descriptive statistics, aggregating data by
# specific variables, or calculating metrics such as total sales, average order value, or
# product category distribution.
# 7. Create visualizations, such as bar plots, pie charts, or box plots, to represent the sales
# data and gain insights into sales trends, customer behavior, or product performance.

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/250.9 kB 1.3 MB/s eta 0:00:01
#    ----------- --------------------------- 71.7/250.9 kB 787.7 kB/s eta 0:00:01
#    ----------------- -------------------- 112.6/250.9 kB 930.9 kB/s eta 0:00:01
#    ------------------ ------------------- 122.9/250.9 kB 901.1 kB/s eta 0:00:01
#    ------------------ ------------------- 122.9/250.9 kB 901.1 kB/s eta 0:00:01
#    ----------------------- -------------- 153.6/250.9 kB 538.9 kB/s eta 0:00:01
#    ------------------------------- ------ 204.8/250.9 kB 655.1 kB/s eta 0:00:01
#    -------------------------------------  245.8/250.9 kB 684.7 kB/s eta 0:00:01
#    -------------------------------------- 250.9/250.9 kB 668.5 kB/s eta 0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# Load CSV data
csv_data = pd.read_csv('./datasets/customers.csv')

# Load Excel data
excel_data = pd.read_excel('./datasets/customers.xlsx', engine='openpyxl')   #openpyxl supports new excel formats

# Load JSON data
with open('./datasets/customers.json', 'r') as json_file:
    json_data = json.load(json_file)
json_data = pd.DataFrame(json_data)

json_data
# Out:
#     first_name last_name                               email  \
# 0       Joseph      Rice      josephrice131@slingacademy.com
# 1         Gary     Moore       garymoore386@slingacademy.com
# 2         John    Walker      johnwalker944@slingacademy.com
# 3         Eric    Carter      ericcarter176@slingacademy.com
# 4      William   Jackson  williamjackson427@slingacademy.com
# ..         ...       ...                                 ...
# 995     Alexis  Williams  alexiswilliams395@slingacademy.com
# 996      Karen    Mendez     karenmendez129@slingacademy.com
# 997   Michaela     Smith   michaelasmith815@slingacademy.com
# 998   Kathleen     Scott   kathleenscott395@slingacademy.com
# 999       Carl    Acosta      carlacosta740@slingacademy.com
#
#                     phone                                            address  \
# 0    +1-800-040-3135x6208             91773 Miller Shoal\nDiaztown, FL 38841
# 1       221.945.4191x8872                6450 John Lodge\nTerriton, KY 95945
# 2       388-142-4883x5370           27265 Murray Island\nKevinfort, PA 63231
# 3           (451)259-5402                          USNS Knight\nFPO AA 76532
# 4        625.626.9133x374            170 Jackson Loaf\nKristenland, AS 48876
# ..                    ...                                                ...
# 995    (659)856-5718x2171  76824 Richards Extensions Suite 123\nDenisevie...
# 996            0339203729   48875 Brown Street\nEast Michelleburgh, KS 22960
# 997  +1-106-147-6378x3133  576 Little Lights Suite 465\nSouth Johnny, PR ...
# 998     (788)465-5647x419  5655 Gross Prairie Suite 656\nWest Jenniferbur...
# 999   +1-183-389-0336x962                   Unit 2581 Box 3388\nDPO AA 71544
#
#      gender  age               registered  orders   spent          job  \
# 0      male   43  2019-05-05T00:00:00.000       7  568.29       Artist
# 1      male   71  2020-05-20T00:00:00.000      11  568.92       Artist
# 2      male   44  2020-04-04T00:00:00.000      11  497.12        Clerk
# 3      male   38  2019-01-30T00:00:00.000      17  834.60      Butcher
# 4      male   58  2022-07-01T00:00:00.000      14  151.59     Engineer
# ..      ...  ...                      ...     ...     ...          ...
# 995  female   34  2019-07-16T00:00:00.000       4  351.18  Firefighter
# 996  female   35  2020-01-30T00:00:00.000       2   45.27      Janitor
# 997  female   23  2019-02-22T00:00:00.000       9  381.57         Chef
# 998  female   72  2019-05-23T00:00:00.000       8  855.10        Clerk
# 999    male   50  2020-01-27T00:00:00.000      20  456.16      Teacher
#
#                          hobbies  is_married
# 0                 Playing sports       False
# 1                       Swimming        True
# 2                       Painting       False
# 3    Playing musical instruments       False
# 4                        Reading       False
# ..                           ...         ...
# 995                       Sewing       False
# 996                       Baking       False
# 997                      Drawing        True
# 998                   Meditation        True
# 999                       Hiking       False
#
# [1000 rows x 13 columns]

# %% [raw]
# #The pd.read_csv function reads the file and loads it into a DataFrame called csv_data. A DataFrame is a table-like data structure with rows and columns, making it easy to manipulate and analyze the data.
#
# #The engine='openpyxl' part specifies that the openpyxl engine should be used, as it supports newer Excel formats (.xlsx files).
#
# #with open('./datasets/customers.json', 'r') as json_file:: Opens a JSON file named customers.json in read mode ('r'). The with statement ensures that the file is automatically closed after reading.
#
# json_data = json.load(json_file): Uses the json.load function to read the contents of the JSON file and converts it into a Python dictionary format, which stores the data in a structured way.
#
# json_data = pd.DataFrame(json_data): Converts the JSON data (which was in dictionary format) into a DataFrame to make it easier to analyze and manipulate. The json_data variable now holds the JSON data in a tabular format similar to the CSV and Excel data.

# %%
# Explore the structure and content of the loaded data
# Identify missing values and data quality issues

print("Structure and Info of CSV Data:")
print(csv_data.info())
print("\nMissing Values in CSV Data:")
print(csv_data.isnull().sum())

print("\nStructure and Info of Excel Data:")
print(excel_data.info())
print("\nMissing Values in Excel Data:")
print(excel_data.isnull().sum())

print("\nStructure and Info of JSON Data:")
print(json_data.info())
print("\nMissing Values in JSON Data:")
print(json_data.isnull().sum())
# Out:
# Structure and Info of CSV Data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   1000 non-null   object
#  2   email       1000 non-null   object
#  3   phone       1000 non-null   object
#  4   address     1000 non-null   object
#  5   gender      1000 non-null   object
#  6   age         1000 non-null   int64
#  7   registered  1000 non-null   object
#  8   orders      1000 non-null   int64
#  9   spent       1000 non-null   float64
#  10  job         1000 non-null   object
#  11  hobbies     1000 non-null   object
#  12  is_married  1000 non-null   bool
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 94.9+ KB
# None
#
# Missing Values in CSV Data:
# first_name    0
# last_name     0
# email         0
# phone         0
# address       0
# gender        0
# age           0
# registered    0
# orders        0
# spent         0
# job           0
# hobbies       0
# is_married    0
# dtype: int64
#
# Structure and Info of Excel Data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   1000 non-null   object
#  2   email       1000 non-null   object
#  3   phone       1000 non-null   object
#  4   address     1000 non-null   object
#  5   gender      1000 non-null   object
#  6   age         1000 non-null   int64
#  7   registered  1000 non-null   datetime64[ns]
#  8   orders      1000 non-null   int64
#  9   spent       1000 non-null   float64
#  10  job         1000 non-null   object
#  11  hobbies     1000 non-null   object
#  12  is_married  1000 non-null   bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(2), object(8)
# memory usage: 94.9+ KB
# None
#
# Missing Values in Excel Data:
# first_name    0
# last_name     0
# email         0
# phone         0
# address       0
# gender        0
# age           0
# registered    0
# orders        0
# spent         0
# job           0
# hobbies       0
# is_married    0
# dtype: int64
#
# Structure and Info of JSON Data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   1000 non-null   object
#  2   email       1000 non-null   object
#  3   phone       1000 non-null   object
#  4   address     1000 non-null   object
#  5   gender      1000 non-null   object
#  6   age         1000 non-null   int64
#  7   registered  1000 non-null   object
#  8   orders      1000 non-null   int64
#  9   spent       1000 non-null   float64
#  10  job         1000 non-null   object
#  11  hobbies     1000 non-null   object
#  12  is_married  1000 non-null   bool
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 94.9+ KB
# None
#
# Missing Values in JSON Data:
# first_name    0
# last_name     0
# email         0
# phone         0
# address       0
# gender        0
# age           0
# registered    0
# orders        0
# spent         0
# job           0
# hobbies       0
# is_married    0
# dtype: int64

# %%
# Handling missing values

csv_data.fillna(0, inplace=True)       #replace missing with 0
excel_data.fillna(0, inplace=True)    #replace missing with 0
json_data.fillna(0, inplace=True)     #replace missing with 0

csv_data.drop_duplicates(inplace=True) #remove duplicates from all columns
excel_data.drop_duplicates(subset=['first_name', 'last_name'], inplace=True) #remove duplicates from ["first_name", "last_name"]
json_data.drop_duplicates(subset=['first_name', 'last_name'], inplace=True) #remove duplicates from ["first_name", "last_name"]

# Print the cleaned data

# %% [raw]
# When we remove duplicates based on a subset of columns (like ['first_name', 'last_name']), we’re telling Python, “Just focus on these columns to find duplicates.” Here’s why we do that instead of checking every column:
#
# Focus on Important Columns: Sometimes, only a few columns (like a person’s name) are essential to identify duplicates. For example, if you have two rows with the same first_name and last_name, it likely means it's the same person, even if other details (like address or phone number) differ.
#
# Ignore Minor Differences: Other columns (like address or email) might have small differences for the same person. If we use all columns to remove duplicates, it might keep both rows because of these minor differences. Using only ['first_name', 'last_name'] ensures we don’t keep unnecessary duplicates.
#
# Save Data: By focusing only on key columns, we avoid deleting useful information in other columns. For example, if one row has an updated phone number, we keep that rather than accidentally deleting it.

# %%
# Merge the datasets
common_df = pd.concat([csv_data, excel_data, json_data], ignore_index=True)

# %%
common_df
# Out:
#      first_name last_name                               email  \
# 0        Joseph      Rice      josephrice131@slingacademy.com
# 1          Gary     Moore       garymoore386@slingacademy.com
# 2          John    Walker      johnwalker944@slingacademy.com
# 3          Eric    Carter      ericcarter176@slingacademy.com
# 4       William   Jackson  williamjackson427@slingacademy.com
# ...         ...       ...                                 ...
# 2965     Alexis  Williams  alexiswilliams395@slingacademy.com
# 2966      Karen    Mendez     karenmendez129@slingacademy.com
# 2967   Michaela     Smith   michaelasmith815@slingacademy.com
# 2968   Kathleen     Scott   kathleenscott395@slingacademy.com
# 2969       Carl    Acosta      carlacosta740@slingacademy.com
#
#                      phone                                            address  \
# 0     +1-800-040-3135x6208             91773 Miller Shoal\nDiaztown, FL 38841
# 1        221.945.4191x8872                6450 John Lodge\nTerriton, KY 95945
# 2        388-142-4883x5370           27265 Murray Island\nKevinfort, PA 63231
# 3            (451)259-5402                          USNS Knight\nFPO AA 76532
# 4         625.626.9133x374            170 Jackson Loaf\nKristenland, AS 48876
# ...                    ...                                                ...
# 2965    (659)856-5718x2171  76824 Richards Extensions Suite 123\nDenisevie...
# 2966            0339203729   48875 Brown Street\nEast Michelleburgh, KS 22960
# 2967  +1-106-147-6378x3133  576 Little Lights Suite 465\nSouth Johnny, PR ...
# 2968     (788)465-5647x419  5655 Gross Prairie Suite 656\nWest Jenniferbur...
# 2969   +1-183-389-0336x962                   Unit 2581 Box 3388\nDPO AA 71544
#
#       gender  age               registered  orders   spent          job  \
# 0       male   43               2019-05-05       7  568.29       Artist
# 1       male   71               2020-05-20      11  568.92       Artist
# 2       male   44               2020-04-04      11  497.12        Clerk
# 3       male   38               2019-01-30      17  834.60      Butcher
# 4       male   58               2022-07-01      14  151.59     Engineer
# ...      ...  ...                      ...     ...     ...          ...
# 2965  female   34  2019-07-16T00:00:00.000       4  351.18  Firefighter
# 2966  female   35  2020-01-30T00:00:00.000       2   45.27      Janitor
# 2967  female   23  2019-02-22T00:00:00.000       9  381.57         Chef
# 2968  female   72  2019-05-23T00:00:00.000       8  855.10        Clerk
# 2969    male   50  2020-01-27T00:00:00.000      20  456.16      Teacher
#
#                           hobbies  is_married
# 0                  Playing sports       False
# 1                        Swimming        True
# 2                        Painting       False
# 3     Playing musical instruments       False
# 4                         Reading       False
# ...                           ...         ...
# 2965                       Sewing       False
# 2966                       Baking       False
# 2967                      Drawing        True
# 2968                   Meditation        True
# 2969                       Hiking       False
#
# [2970 rows x 13 columns]

# %%
# Split a column and create new variables
common_df['phone_area_code'] = common_df['phone'].str.extract(r'(\d+)')
# Derive a new variable
common_df['full_name'] = common_df['first_name'] + " " + common_df['last_name']

# Print the transformed DataFrame
common_df
# Out:
#      first_name last_name                               email  \
# 0        Joseph      Rice      josephrice131@slingacademy.com
# 1          Gary     Moore       garymoore386@slingacademy.com
# 2          John    Walker      johnwalker944@slingacademy.com
# 3          Eric    Carter      ericcarter176@slingacademy.com
# 4       William   Jackson  williamjackson427@slingacademy.com
# ...         ...       ...                                 ...
# 2965     Alexis  Williams  alexiswilliams395@slingacademy.com
# 2966      Karen    Mendez     karenmendez129@slingacademy.com
# 2967   Michaela     Smith   michaelasmith815@slingacademy.com
# 2968   Kathleen     Scott   kathleenscott395@slingacademy.com
# 2969       Carl    Acosta      carlacosta740@slingacademy.com
#
#                      phone                                            address  \
# 0     +1-800-040-3135x6208             91773 Miller Shoal\nDiaztown, FL 38841
# 1        221.945.4191x8872                6450 John Lodge\nTerriton, KY 95945
# 2        388-142-4883x5370           27265 Murray Island\nKevinfort, PA 63231
# 3            (451)259-5402                          USNS Knight\nFPO AA 76532
# 4         625.626.9133x374            170 Jackson Loaf\nKristenland, AS 48876
# ...                    ...                                                ...
# 2965    (659)856-5718x2171  76824 Richards Extensions Suite 123\nDenisevie...
# 2966            0339203729   48875 Brown Street\nEast Michelleburgh, KS 22960
# 2967  +1-106-147-6378x3133  576 Little Lights Suite 465\nSouth Johnny, PR ...
# 2968     (788)465-5647x419  5655 Gross Prairie Suite 656\nWest Jenniferbur...
# 2969   +1-183-389-0336x962                   Unit 2581 Box 3388\nDPO AA 71544
#
#       gender  age               registered  orders   spent          job  \
# 0       male   43               2019-05-05       7  568.29       Artist
# 1       male   71               2020-05-20      11  568.92       Artist
# 2       male   44               2020-04-04      11  497.12        Clerk
# 3       male   38               2019-01-30      17  834.60      Butcher
# 4       male   58               2022-07-01      14  151.59     Engineer
# ...      ...  ...                      ...     ...     ...          ...
# 2965  female   34  2019-07-16T00:00:00.000       4  351.18  Firefighter
# 2966  female   35  2020-01-30T00:00:00.000       2   45.27      Janitor
# 2967  female   23  2019-02-22T00:00:00.000       9  381.57         Chef
# 2968  female   72  2019-05-23T00:00:00.000       8  855.10        Clerk
# 2969    male   50  2020-01-27T00:00:00.000      20  456.16      Teacher
#
#                           hobbies  is_married phone_area_code        full_name
# 0                  Playing sports       False               1      Joseph Rice
# 1                        Swimming        True             221       Gary Moore
# 2                        Painting       False             388      John Walker
# 3     Playing musical instruments       False             451      Eric Carter
# 4                         Reading       False             625  William Jackson
# ...                           ...         ...             ...              ...
# 2965                       Sewing       False             659  Alexis Williams
# 2966                       Baking       False      0339203729     Karen Mendez
# 2967                      Drawing        True               1   Michaela Smith
# 2968                   Meditation        True             788   Kathleen Scott
# 2969                       Hiking       False               1      Carl Acosta
#
# [2970 rows x 15 columns]

# %% [raw]
# common_df['phone'].str.extract(r'(\d+)'): This uses .str.extract() with a regular expression (r'(\d+)').
# r'(\d+)': The regular expression \d+ matches any sequence of digits. The parentheses () capture this sequence, allowing it to be extracted.
# So, common_df['phone_area_code'] will contain the first set of digits in each phone number, typically the area code or a country code, depending on the data format.

# %%
# Perform descriptive statistics
desc_stats = common_df.describe() #get descriptive stats

total_sales = common_df['spent'].sum() #calc total sales

average_order_value = common_df['spent'].mean() #avg order value

product_distribution = common_df['job'].value_counts()     # calculate product category distribution

print(desc_stats)
print(product_distribution)
print(average_order_value)
# Out:
#                age       orders        spent
# count  2970.000000  2970.000000  2970.000000
# mean     48.139057    10.051852   495.715172
# std      18.366168     6.172550   288.936894
# min      18.000000     0.000000     0.490000
# 25%      32.000000     5.000000   246.660000
# 50%      47.000000    10.000000   468.740000
# 75%      64.000000    15.000000   739.295000
# max      80.000000    20.000000   999.150000
# job
# Lawyer            109
# Barber            105
# Tailor            102
# Receptionist      102
# Accountant        102
# Mechanic           99
# Butcher            96
# Chef               94
# Doctor             94
# Baker              93
# Dentist            90
# Janitor            90
# Unemployed         82
# Hairdresser        81
# Athlete            81
# Security Guard     81
# Cashier            78
# Firefighter        78
# Student            76
# Engineer           76
# Housewife          76
# Waitress           75
# Polic              75
# Waiter             75
# Nurse              75
# Architect          72
# Teacher            72
# Pilot              72
# Clerk              72
# Artist             72
# Farmer             69
# Politician         67
# Unkown             64
# Scientist          63
# Officer            60
# Carpenter          60
# Librarian          42
# Name: count, dtype: int64
# 495.71517171717176

# %%
# Create a bar plot to represent sales by product category
sns.barplot(x='job', y='spent', data=common_df)
plt.title('Sales by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Sales')
plt.xticks(rotation=90)
plt.show()

# Create a pie chart to represent the distribution of product categories
product_distribution = common_df['job'].value_counts()
plt.pie(product_distribution, labels=product_distribution.index, autopct='%1.1f%%', startangle=140)
plt.title('job Category Distribution')
plt.xticks(rotation=90)
plt.show()

# Create a box plot to visualize the distribution of order values
sns.boxplot(x='job', y='spent', data=common_df)
plt.title('Order Value Distribution by Job')
plt.xlabel('Job')
plt.ylabel('Order Value')
plt.xticks(rotation=90)
plt.show()
